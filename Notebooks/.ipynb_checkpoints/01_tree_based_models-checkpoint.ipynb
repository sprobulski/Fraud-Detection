# %% [markdown]
# # Modeling and Evaluation
#
# In this section, we develop and evaluate several machine learning models for detecting fraudulent transactions. Due to the highly imbalanced nature of the dataset, we apply oversampling techniques (SMOTE and ADASYN) to improve the detection of the minority class (fraud).
#
# The following classification algorithms are considered:
# - Random Forest
# - XGBoost
# - (Optionally: LightGBM, CatBoost)
#
# We assess model performance using:
# - F1-score (key for imbalanced problems),
# - Precision and Recall,
# - ROC AUC and PR AUC,
# - Confusion Matrix.
#
# Each model is trained and evaluated using three different versions of the training data:
# - Original (unbalanced),
# - SMOTE oversampled,
# - ADASYN oversampled.

# %%
# library imports
import pandas as pd
import joblib
import xgboost as xgb
import catboost as cb
import time

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from imblearn.over_sampling import SMOTE, ADASYN


import sys
sys.path.append('../') 

from src.Helper_functions import get_results, plot_roc_curve, plot_pr_curve,find_best_f1_threshold

# %%
# Load the dataset
card_data = pd.read_csv('../creditcard.csv')

# %% [markdown]
# ## Data Preparation
#
# - The `Time` column is removed, as it does not contribute predictive value.
# - The target variable is `Class`: `0` for legitimate transactions, `1` for fraud.
# - The dataset is split into training and testing sets using an 99/1 ratio, with stratification to preserve the class distribution.
#
# To address class imbalance, we apply two oversampling techniques to the training data only:
# - **SMOTE**: Synthetic Minority Oversampling Technique, which generates new samples based on nearest neighbors.
# - **ADASYN**: Adaptive Synthetic Sampling, which focuses more on generating difficult or borderline examples.

# %%
# Assign the features and target variable
# Note: 'Time' is dropped as it is not relevant for the model
X = card_data.drop(['Time','Class'],axis = 1)
y = card_data['Class']

# split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y,stratify=y, test_size=0.2, random_state=42)

print("Class distribution in training set:")
print(y_train.value_counts(normalize=True))

print("\n Class distribution in test set:")
print(y_test.value_counts(normalize=True))

# Apply SMOTE and ADASYN to balance the dataset
# Note: The sampling strategy is set to 0.01 to keep the number of positive samples low
smote = SMOTE(random_state=42, sampling_strategy=0.01)
X_res, y_res = smote.fit_resample(X_train, y_train)
print("\n Class distribution after SMOTE:")
print(pd.Series(y_res).value_counts(normalize=True))

adasyn = ADASYN(random_state=42, sampling_strategy=0.01)
X_res_adasyn, y_res_adasyn = adasyn.fit_resample(X_train, y_train)
print("\n Class distribution after ADASYN:")
print(pd.Series(y_res_adasyn).value_counts(normalize=True))
# Out:
# Class distribution in training set:
# Class
# 0    0.998271
# 1    0.001729
# Name: proportion, dtype: float64
#
#  Class distribution in test set:
# Class
# 0    0.99828
# 1    0.00172
# Name: proportion, dtype: float64
#
#  Class distribution after SMOTE:
# Class
# 0    0.990101
# 1    0.009899
# Name: proportion, dtype: float64
#
#  Class distribution after ADASYN:
# Class
# 0    0.989834
# 1    0.010166
# Name: proportion, dtype: float64

# %% [markdown]
# > **Note on Threshold Optimization**
# > Instead of using the default classification threshold of 0.5, we optimize the decision threshold to **maximize the F1-score** on the validation set.
# > In fraud detection, there's often a trade-off between **precision** (avoiding false alarms) and **recall** (catching as many fraudulent transactions as possible).
# > Since the business context does not clearly prioritize one over the other, the F1-score — which balances both — serves as a fair and effective optimization target.

# %% [markdown]
# # Model 1: Random Forest
#
# Random Forest is an ensemble model based on decision trees that performs well in nonlinear classification problems. The model is trained with class weights (`class_weight='balanced'`) to handle imbalance, and hyperparameter tuning is performed using Grid Search.
#
# Tuned hyperparameters include:
# - `max_depth`: Maximum depth of each tree,
# - `min_samples_split`: Minimum number of samples required to split an internal node,
# - `min_samples_leaf`: Minimum number of samples required to be at a leaf node.
#
# The model is trained separately on:
# - Original data,
# - SMOTE oversampled data,
# - ADASYN oversampled data.

# %%
# Define the random forest model
model_rf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

param_grid = {
    'max_depth': [10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %% [markdown]
# **RF model without oversampling**

# %%
# Perform grid search with cross-validation
# Start timing the grid search
timing_results = []
start = time.time()

grid_rf = GridSearchCV(model_rf, param_grid=param_grid, cv=2, scoring='f1', n_jobs=-1).fit(X_train, y_train)

end = time.time()
timing_results.append({
    "model": "RandomForest",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score
print("Best parameters found: ", grid_rf.best_params_)
print("Best F1 score: ", grid_rf.best_score_)

# Save the model
joblib.dump(grid_rf, '../models/rf_grid_search.pkl')
print("Model saved to '../models/rf_grid_search.pkl'")
# Out:
# Best parameters found:  {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5}
# Best F1 score:  0.8256899558838617
# Model saved to '../models/rf_grid_search.pkl'

# %%
# Load the random forest model
loaded_model_rf = joblib.load('../models/rf_grid_search.pkl')
y_pred_rf_proba = loaded_model_rf.predict_proba(X_test)[:, 1]
y_pred_train_rf_proba = loaded_model_rf.predict_proba(X_train)[:, 1]

# Find the best threshold for F1 score
threshold_rf = find_best_f1_threshold(X_test,y_test,model = loaded_model_rf)

# Calculate the treshold optimizing f1 score
print(f"Best threshold for F1 score: {threshold_rf}")

# Plot the Precision-Recall curve vs Threshold
# Calculate other metrics based on the threshold
print("Results without oversampling:")
results_rf = get_results(y_test, y_pred_rf_proba, y_train, y_pred_train_rf_proba, threshold_rf)

# Plot ROC and PR curves
roc_rf = plot_roc_curve(loaded_model_rf, X_test, y_test)
pr_auc_rf = plot_pr_curve(loaded_model_rf, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Results without oversampling:
# Metrics for test
# Accuracy: 0.9995
# Precision: 0.8913
# Recall: 0.8367
# F1: 0.8632
#
# Metrics for train
# Accuracy: 0.9999
# Precision: 0.9381
# Recall: 1.0000
# F1: 0.9681
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.84      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.92      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9519
# PR AUC: 0.8614

# %% [markdown]
# **RF model with SMOTE oversampling**

# %%
# Perform grid search with cross-validation
# Start timing the grid search
# X_res and y_res are the resampled training data using SMOTE

start = time.time()
grid_rf_smote = GridSearchCV(model_rf, param_grid=param_grid, cv=2, scoring='f1', n_jobs=-1).fit(X_res, y_res)
end = time.time()
timing_results.append({
    "model": "RandomForest SMOTE",
    "training time (sec)": round(end - start, 2)
})

 # Print the best parameters and best score
print("Best parameters found: ", grid_rf_smote.best_params_)
print("Best F1 score: ", grid_rf_smote.best_score_)

# Save the model
joblib.dump(grid_rf_smote, '../models/rf_grid_search_smote.pkl')
print("Model saved to '../models/rf_grid_search_smote.pkl'")
# Out:
# Best parameters found:  {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best F1 score:  0.9320345332440266
# Model saved to '../models/rf_grid_search_smote.pkl'

# %%
# Load the model with SMOTE
loaded_model_rf_smote = joblib.load('../models/rf_grid_search_smote.pkl')

y_pred_rf_smote_proba = loaded_model_rf_smote.predict_proba(X_test)[:, 1]
y_pred_train_rf_smote_proba = loaded_model_rf_smote.predict_proba(X_res)[:, 1]

# Find the best threshold for F1 score with SMOTE
threshold_rf_smote = find_best_f1_threshold(X_test, y_test, model=loaded_model_rf_smote)

# Calculate the treshold optimizing f1 score
print(f"Best threshold for F1 score with SMOTE: {threshold_rf_smote}")

# Calculate other metrics based on the threshold with SMOTE
print("Results with SMOTE:")
results_rf_smote = get_results(y_test, y_pred_rf_smote_proba, y_res, y_pred_train_rf_smote_proba, threshold_rf_smote)

# Plot ROC and PR curves with SMOTE
roc_rf_smote = plot_roc_curve(loaded_model_rf_smote, X_test, y_test)
pr_auc_rf_smote = plot_pr_curve(loaded_model_rf_smote, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.9398
# Recall: 0.7959
# F1: 0.8619
#
# Metrics for train
# Accuracy: 0.9999
# Precision: 0.9943
# Recall: 0.9930
# F1: 0.9936
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.80      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.90      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9553
# PR AUC: 0.8605

# %% [markdown]
# **RF model with ADYSYN oversampling**

# %%
# Perform grid search with cross-validation for ADASYN
# X_res_adasyn and y_res_adasyn are the resampled training data using ADASYN
start = time.time()
grid_rf_adysyn = GridSearchCV(model_rf, param_grid=param_grid, cv=2, scoring='f1', n_jobs=-1).fit(X_res_adasyn, y_res_adasyn)
end = time.time()
timing_results.append({
    "model": "RandomForest ADASYN",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for ADASYN
print("Best parameters found: ", grid_rf_adysyn.best_params_)
print("Best F1 score: ", grid_rf_adysyn.best_score_)

# Save the model with ADASYN
joblib.dump(grid_rf_adysyn, '../models/rf_grid_search_adysyn.pkl')
print("Model saved to '../models/rf_grid_search_adysyn.pkl'")
# Out:
# Best parameters found:  {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2}
# Best F1 score:  0.8528967839312667
# Model saved to '../models/rf_grid_search_adysyn.pkl'

# %%
# Load the model with ADASYN
loaded_model_rf_adysyn = joblib.load('../models/rf_grid_search_adysyn.pkl')

y_pred_rf_adysyn = loaded_model_rf_adysyn.predict_proba(X_test)[:, 1]
y_pred_train_rf_adysyn_proba = loaded_model_rf_adysyn.predict_proba(X_res_adasyn)[:, 1]

# Find the best threshold for F1 score with ADASYN
threshold_rf_adysyn_proba = find_best_f1_threshold(X_test, y_test, model=loaded_model_rf_adysyn)

# Calculate the treshold optimizing f1 score with ADASYN
print(f"Best threshold for F1 score with ADASYN: {threshold_rf_adysyn_proba}")

# Calculate other metrics based on the threshold with ADASYN
print("Results with ADASYN:")
results_rf_adysyn = get_results(y_test, y_pred_rf_adysyn, y_res_adasyn, y_pred_train_rf_adysyn_proba, threshold_rf_adysyn_proba)

# Plot ROC and PR curves with ADASYN
roc_rf_adasyn = plot_roc_curve(loaded_model_rf_adysyn, X_test, y_test)
pr_auc_rf_adasyn = plot_pr_curve(loaded_model_rf_adysyn, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.9620
# Recall: 0.7755
# F1: 0.8588
#
# Metrics for train
# Accuracy: 0.9996
# Precision: 0.9965
# Recall: 0.9675
# F1: 0.9818
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.78      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9693
# PR AUC: 0.8753

# %% [markdown]
# # Model 2: XGBoost
#
# XGBoost (Extreme Gradient Boosting) is a high-performance implementation of gradient boosting designed for speed and accuracy. It is particularly effective for structured/tabular data and supports regularization to combat overfitting.
#
# For this project, XGBoost is trained with hyperparameter tuning via Grid Search. The search space includes:
#
# - `max_depth` — Maximum depth of a tree. Increasing depth allows the model to capture more complexity but may lead to overfitting.
# - `min_child_weight` — Minimum sum of instance weights (hessian) needed in a child. Higher values make the algorithm more conservative.
# - `colsample_bytree` — Subsample ratio of columns when constructing each tree. Used to prevent overfitting.
# - `reg_alpha` — L1 regularization term on weights.
# - `reg_lambda` — L2 regularization term on weights.
#
# As before, the model is trained and evaluated on three datasets:
# - Original (imbalanced),
# - SMOTE-oversampled,
# - ADASYN-oversampled.
#
# The best parameters are selected based on cross-validated F1-score.

# %% [markdown]
# # XGBoost

# %% [markdown]
# **XGBoost without oversampling**

# %%
# XGBoost model with hyperparameter tuning
# Define the scale_pos_weight for XGBoost
# Calculate the scale_pos_weight based on the class distribution in the training set
# This is used to handle class imbalance
# The scale_pos_weight is the ratio of the number of negative samples to the number of positive samples
# This helps the model to pay more attention to the minority class (fraudulent transactions)

scale_pos_weight = len(y_train[y_train == 0]) / len(y_train[y_train == 1])

model_xgb = xgb.XGBClassifier(eval_metric='logloss', random_state=42, scale_pos_weight=scale_pos_weight, n_estimators=200)
param_grid_xgb = {
    'max_depth': [2, 5, 10],
    'min_child_weight': [1, 2],
    'colsample_bytree': [0.8, 1.0],
    'reg_alpha': [0, 0.1, 0.5],
    'reg_lambda': [0.1, 0.5, 1.0],
}
start = time.time()
grid_xgb = GridSearchCV(model_xgb, param_grid=param_grid_xgb, cv=3, scoring='f1', n_jobs=-1).fit(X_train, y_train)
end = time.time()
timing_results.append({
    "model": "XGBoost",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for XGBoost
print("Best parameters found for XGBoost: ", grid_xgb.best_params_)
print("Best F1 score for XGBoost: ", grid_xgb.best_score_)

# Save the XGBoost model
joblib.dump(grid_xgb, '../models/xgb_grid_search.pkl')
print("XGBoost model saved to '../models/xgb_grid_search.pkl'")
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:59:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best parameters found for XGBoost:  {'colsample_bytree': 0.8, 'max_depth': 10, 'min_child_weight': 1, 'reg_alpha': 0.5, 'reg_lambda': 0.1}
# Best F1 score for XGBoost:  0.8551610325817706
# XGBoost model saved to '../models/xgb_grid_search.pkl'

# %%
# Load the model
loaded_model_xgb = joblib.load('../models/xgb_grid_search.pkl')

# Predict probabilities for the test and training sets using the loaded XGBoost model
y_pred_xgb_proba = loaded_model_xgb.predict_proba(X_test)[:, 1]
y_pred_train_xgb_proba = loaded_model_xgb.predict_proba(X_train)[:, 1]

# Find the best threshold for F1 score for XGBoost
threshold_xgb = find_best_f1_threshold(X_test, y_test, model=loaded_model_xgb)

# Calculate the treshold optimizing f1 score for XGBoost
print(f"Best threshold for F1 score for XGBoost: {threshold_xgb}")

# Calculate other metrics based on the threshold for XGBoost
results_xgb = get_results(y_test, y_pred_xgb_proba, y_train, y_pred_train_xgb_proba,threshold_xgb)

# Plot ROC and PR curves for XGBoost
roc_xgb = plot_roc_curve(loaded_model_xgb, X_test, y_test)
pr_auc_xgb = plot_pr_curve(loaded_model_xgb, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.9195
# Recall: 0.8163
# F1: 0.8649
#
# Metrics for train
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.92      0.82      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.91      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9727
# PR AUC: 0.8773

# %% [markdown]
# **XGBoost with SMOTE**

# %%
# XGBoost model with SMOTE
# Define the scale_pos_weight for XGBoost with SMOTE and ADASYN
scale_pos_weight_oversample = len(y_res[y_res == 0]) / len(y_res[y_res == 1])

# Create a new XGBoost model with the calculated scale_pos_weight
model_xgb_oversample = xgb.XGBClassifier(eval_metric='logloss', random_state=42, scale_pos_weight=scale_pos_weight_oversample, n_estimators=200)

# Perform grid search with cross-validation for XGBoost with SMOTE
start = time.time()
grid_xgb_smote = GridSearchCV(model_xgb_oversample, param_grid=param_grid_xgb, cv=3, scoring='f1', n_jobs=-1).fit(X_res, y_res)
end = time.time()
timing_results.append({
    "model": "XGBoost SMOTE",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for XGBoost with SMOTE
print("Best parameters found for XGBoost with SMOTE: ", grid_xgb_smote.best_params_)
print("Best F1 score for XGBoost with SMOTE: ", grid_xgb_smote.best_score_)

# Save the XGBoost model with SMOTE
joblib.dump(grid_xgb_smote, '../models/xgb_grid_search_smote.pkl')
print("XGBoost with SMOTE model saved to '../models/xgb_grid_search_smote.pkl'")
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:22:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best parameters found for XGBoost with SMOTE:  {'colsample_bytree': 0.8, 'max_depth': 5, 'min_child_weight': 2, 'reg_alpha': 0.1, 'reg_lambda': 0.1}
# Best F1 score for XGBoost with SMOTE:  0.9691861106933355
# XGBoost with SMOTE model saved to '../models/xgb_grid_search_smote.pkl'

# %%
# Load the model
loaded_model_xgb_smote = joblib.load('../models/xgb_grid_search_smote.pkl')

# Predict probabilities for the test and training sets using the loaded XGBoost model with SMOTE
y_pred_xgb_smote_proba = loaded_model_xgb_smote.predict_proba(X_test)[:, 1]
y_pred_train_xgb_smote_proba = loaded_model_xgb_smote.predict_proba(X_res)[:, 1]

# Find the best threshold for F1 score for XGBoost with SMOTE
threshold_xgb_smote = find_best_f1_threshold(X_test, y_test, model=loaded_model_xgb_smote)

# Calculate the treshold optimizing f1 score for XGBoost with SMOTE
print(f"Best threshold for F1 score for XGBoost with SMOTE: {threshold_xgb_smote}")

# Calculate other metrics based on the threshold for XGBoost with SMOTE
results_xgb_smote = get_results(y_test, y_pred_xgb_smote_proba, y_res, y_pred_train_xgb_smote_proba, threshold_xgb_smote)

# Plot ROC and PR curves for XGBoost with SMOTE
roc_xgb_smote = plot_roc_curve(loaded_model_xgb_smote, X_test, y_test)
pr_auc_xgb_smote = plot_pr_curve(loaded_model_xgb_smote, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.8936
# Recall: 0.8571
# F1: 0.8750
#
# Metrics for train
# Accuracy: 1.0000
# Precision: 0.9996
# Recall: 1.0000
# F1: 0.9998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.86      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.93      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9769
# PR AUC: 0.8847

# %% [markdown]
# **XGBoost with ADASYN**

# %%
# XGBoost model with ADASYN
# Create a new XGBoost model with the calculated scale_pos_weight for ADASYN
start = time.time()
grid_xgb_adasyn = GridSearchCV(model_xgb_oversample, param_grid=param_grid_xgb, cv=3, scoring='f1', n_jobs=-1).fit(X_res_adasyn, y_res_adasyn)
end = time.time()
timing_results.append({
    "model": "XGBoost ADASYN",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for XGBoost with ADASYN
print("Best parameters found for XGBoost with ADASYN: ", grid_xgb_adasyn.best_params_)
print("Best F1 score for XGBoost with ADASYN: ", grid_xgb_adasyn.best_score_)

# Save the XGBoost model with ADASYN
joblib.dump(grid_xgb_adasyn, '../models/xgb_grid_search_adasyn.pkl')
print("XGBoost with ADASYN model saved to '../models/xgb_grid_search_adasyn.pkl'")
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:04:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best parameters found for XGBoost with ADASYN:  {'colsample_bytree': 1.0, 'max_depth': 5, 'min_child_weight': 1, 'reg_alpha': 0, 'reg_lambda': 1.0}
# Best F1 score for XGBoost with ADASYN:  0.95174242743728
# XGBoost with ADASYN model saved to '../models/xgb_grid_search_adasyn.pkl'

# %%
# Load the model
loaded_model_xgb_adasyn = joblib.load('../models/xgb_grid_search_adasyn.pkl')

# Predict probabilities for the test and training sets using the loaded XGBoost model with ADASYN
y_pred_xgb_adasyn_proba = loaded_model_xgb_adasyn.predict_proba(X_test)[:, 1]
y_pred_train_xgb_adasyn_proba = loaded_model_xgb_adasyn.predict_proba(X_res_adasyn)[:, 1]

# Find the best threshold for F1 score for XGBoost with ADASYN
threshold_xgb_adasyn = find_best_f1_threshold(X_test, y_test, model=loaded_model_xgb_adasyn)

# Calculate the treshold optimizing f1 score for XGBoost with ADASYN
print(f"Best threshold for F1 score for XGBoost with ADASYN: {threshold_xgb_adasyn}")

# Calculate other metrics based on the threshold for XGBoost with ADASYN
print("Results with ADASYN:")
results_xgb_adasyn = get_results(y_test, y_pred_xgb_adasyn_proba, y_res_adasyn, y_pred_train_xgb_adasyn_proba, threshold_xgb_adasyn)

# Plot ROC and PR curves for XGBoost with ADASYN
roc_xgb_adasyn = plot_roc_curve(loaded_model_xgb_adasyn, X_test, y_test)
pr_auc_xgb_adasyn = plot_pr_curve(loaded_model_xgb_adasyn, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.9506
# Recall: 0.7857
# F1: 0.8603
#
# Metrics for train
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 0.9996
# F1: 0.9998
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.79      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9782
# PR AUC: 0.8719

# %% [markdown]
# # Model 3: CatBoost
#
# CatBoost is a gradient boosting algorithm developed by Yandex. It is designed to handle categorical features natively and often performs well with minimal hyperparameter tuning. In this case, we still apply grid search to explore several key parameters.
#
# The following hyperparameters were tuned:
#
# - `depth` — Depth of the trees. Deeper trees can model more complex patterns.
# - `learning_rate` — Controls how quickly the model adapts to the problem. Lower values lead to slower but more stable convergence.
# - `l2_leaf_reg` — L2 regularization term. Helps prevent overfitting.
# - `min_data_in_leaf` — Minimum number of training samples in a leaf.
#
# Just like the previous models, CatBoost is trained on:
# - The original dataset,
# - Data oversampled using SMOTE,
# - Data oversampled using ADASYN.
#
# The best model configuration is selected using cross-validation based on F1-score.

# %%
# CatBoost model with hyperparameter tuning
# The scale_pos_weitght is the same as for XGBoost, calculated based on the class distribution in the training set

model_cb = cb.CatBoostClassifier(eval_metric='Logloss', random_state=42, scale_pos_weight=scale_pos_weight, iterations=200,early_stopping_rounds=20)
param_grid_cb = {
    'depth': [4,6],
    'learning_rate': [0.01, 0.05, 0.1],
    'l2_leaf_reg': [1, 3],
    'min_data_in_leaf': [1, 5]
}

start = time.time() 
grid_cb = GridSearchCV(model_cb, param_grid=param_grid_cb, cv=3, scoring='f1', n_jobs=-1).fit(X_train, y_train)
end = time.time()
timing_results.append({
    "model": "CatBoost",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for CatBoost
print("Best parameters found for CatBoost: ", grid_cb.best_params_)
print("Best F1 score for CatBoost: ", grid_cb.best_score_)

# Save the CatBoost model
joblib.dump(grid_cb, '../models/cb_grid_search.pkl')
print("CatBoost model saved to '../models/cb_grid_search.pkl'")
# Out:
# 0:	learn: 0.5366367	total: 160ms	remaining: 31.8s
# 1:	learn: 0.4239561	total: 189ms	remaining: 18.7s
# 2:	learn: 0.3457232	total: 212ms	remaining: 13.9s
# 3:	learn: 0.2962968	total: 238ms	remaining: 11.6s
# 4:	learn: 0.2480961	total: 261ms	remaining: 10.2s
# 5:	learn: 0.2160560	total: 288ms	remaining: 9.33s
# 6:	learn: 0.1960324	total: 313ms	remaining: 8.63s
# 7:	learn: 0.1759935	total: 336ms	remaining: 8.06s
# 8:	learn: 0.1616296	total: 360ms	remaining: 7.64s
# 9:	learn: 0.1386644	total: 383ms	remaining: 7.28s
# 10:	learn: 0.1292493	total: 413ms	remaining: 7.09s
# 11:	learn: 0.1224341	total: 438ms	remaining: 6.87s
# 12:	learn: 0.1154911	total: 463ms	remaining: 6.66s
# 13:	learn: 0.1092091	total: 489ms	remaining: 6.5s
# 14:	learn: 0.0990777	total: 514ms	remaining: 6.33s
# 15:	learn: 0.0943394	total: 542ms	remaining: 6.24s
# 16:	learn: 0.0902048	total: 568ms	remaining: 6.11s
# 17:	learn: 0.0859498	total: 594ms	remaining: 6s
# 18:	learn: 0.0813145	total: 623ms	remaining: 5.93s
# 19:	learn: 0.0742401	total: 658ms	remaining: 5.92s
# 20:	learn: 0.0703430	total: 683ms	remaining: 5.82s
# 21:	learn: 0.0666116	total: 707ms	remaining: 5.72s
# 22:	learn: 0.0640771	total: 734ms	remaining: 5.64s
# 23:	learn: 0.0606987	total: 757ms	remaining: 5.55s
# 24:	learn: 0.0576471	total: 781ms	remaining: 5.47s
# 25:	learn: 0.0562523	total: 805ms	remaining: 5.39s
# 26:	learn: 0.0547305	total: 829ms	remaining: 5.31s
# 27:	learn: 0.0513576	total: 854ms	remaining: 5.24s
# 28:	learn: 0.0493537	total: 878ms	remaining: 5.18s
# 29:	learn: 0.0478060	total: 903ms	remaining: 5.12s
# 30:	learn: 0.0458712	total: 927ms	remaining: 5.05s
# 31:	learn: 0.0437693	total: 950ms	remaining: 4.99s
# 32:	learn: 0.0422907	total: 974ms	remaining: 4.93s
# 33:	learn: 0.0409577	total: 997ms	remaining: 4.87s
# 34:	learn: 0.0393720	total: 1.02s	remaining: 4.8s
# 35:	learn: 0.0385292	total: 1.04s	remaining: 4.75s
# 36:	learn: 0.0365789	total: 1.07s	remaining: 4.71s
# 37:	learn: 0.0351909	total: 1.09s	remaining: 4.67s
# 38:	learn: 0.0335054	total: 1.12s	remaining: 4.62s
# 39:	learn: 0.0318854	total: 1.14s	remaining: 4.58s
# 40:	learn: 0.0306722	total: 1.17s	remaining: 4.54s
# 41:	learn: 0.0290860	total: 1.2s	remaining: 4.5s
# 42:	learn: 0.0275262	total: 1.22s	remaining: 4.45s
# 43:	learn: 0.0266904	total: 1.24s	remaining: 4.41s
# 44:	learn: 0.0259200	total: 1.27s	remaining: 4.36s
# 45:	learn: 0.0247337	total: 1.29s	remaining: 4.32s
# 46:	learn: 0.0235493	total: 1.32s	remaining: 4.29s
# 47:	learn: 0.0230972	total: 1.34s	remaining: 4.25s
# 48:	learn: 0.0225016	total: 1.36s	remaining: 4.2s
# 49:	learn: 0.0217726	total: 1.39s	remaining: 4.16s
# 50:	learn: 0.0206220	total: 1.41s	remaining: 4.12s
# 51:	learn: 0.0197396	total: 1.44s	remaining: 4.08s
# 52:	learn: 0.0191828	total: 1.46s	remaining: 4.05s
# 53:	learn: 0.0186887	total: 1.48s	remaining: 4.01s
# 54:	learn: 0.0179538	total: 1.51s	remaining: 3.98s
# 55:	learn: 0.0174589	total: 1.53s	remaining: 3.94s
# 56:	learn: 0.0166801	total: 1.55s	remaining: 3.9s
# 57:	learn: 0.0159626	total: 1.58s	remaining: 3.86s
# 58:	learn: 0.0154665	total: 1.6s	remaining: 3.83s
# 59:	learn: 0.0151449	total: 1.63s	remaining: 3.8s
# 60:	learn: 0.0146059	total: 1.66s	remaining: 3.77s
# 61:	learn: 0.0136995	total: 1.68s	remaining: 3.74s
# 62:	learn: 0.0133097	total: 1.71s	remaining: 3.72s
# 63:	learn: 0.0131686	total: 1.74s	remaining: 3.7s
# 64:	learn: 0.0128908	total: 1.76s	remaining: 3.66s
# 65:	learn: 0.0125511	total: 1.79s	remaining: 3.63s
# 66:	learn: 0.0120609	total: 1.81s	remaining: 3.6s
# 67:	learn: 0.0118387	total: 1.84s	remaining: 3.57s
# 68:	learn: 0.0113514	total: 1.87s	remaining: 3.54s
# 69:	learn: 0.0107864	total: 1.89s	remaining: 3.52s
# 70:	learn: 0.0105233	total: 1.92s	remaining: 3.49s
# 71:	learn: 0.0102113	total: 1.95s	remaining: 3.46s
# 72:	learn: 0.0099539	total: 1.98s	remaining: 3.44s
# 73:	learn: 0.0097378	total: 2s	remaining: 3.41s
# 74:	learn: 0.0093316	total: 2.02s	remaining: 3.37s
# 75:	learn: 0.0090955	total: 2.05s	remaining: 3.35s
# 76:	learn: 0.0089801	total: 2.07s	remaining: 3.31s
# 77:	learn: 0.0087776	total: 2.1s	remaining: 3.29s
# 78:	learn: 0.0086685	total: 2.13s	remaining: 3.25s
# 79:	learn: 0.0085049	total: 2.15s	remaining: 3.23s
# 80:	learn: 0.0082732	total: 2.18s	remaining: 3.2s
# 81:	learn: 0.0081259	total: 2.2s	remaining: 3.17s
# 82:	learn: 0.0078785	total: 2.22s	remaining: 3.13s
# 83:	learn: 0.0076991	total: 2.25s	remaining: 3.1s
# 84:	learn: 0.0074942	total: 2.27s	remaining: 3.07s
# 85:	learn: 0.0073691	total: 2.3s	remaining: 3.05s
# 86:	learn: 0.0071673	total: 2.33s	remaining: 3.03s
# 87:	learn: 0.0070795	total: 2.36s	remaining: 3.01s
# 88:	learn: 0.0069721	total: 2.39s	remaining: 2.98s
# 89:	learn: 0.0067924	total: 2.42s	remaining: 2.95s
# 90:	learn: 0.0066390	total: 2.45s	remaining: 2.93s
# 91:	learn: 0.0065142	total: 2.48s	remaining: 2.91s
# 92:	learn: 0.0062501	total: 2.52s	remaining: 2.9s
# 93:	learn: 0.0061176	total: 2.56s	remaining: 2.89s
# 94:	learn: 0.0058971	total: 2.59s	remaining: 2.86s
# 95:	learn: 0.0057986	total: 2.62s	remaining: 2.83s
# 96:	learn: 0.0057047	total: 2.65s	remaining: 2.81s
# 97:	learn: 0.0055093	total: 2.68s	remaining: 2.79s
# 98:	learn: 0.0053635	total: 2.72s	remaining: 2.77s
# 99:	learn: 0.0052163	total: 2.75s	remaining: 2.75s
# 100:	learn: 0.0051102	total: 2.78s	remaining: 2.72s
# 101:	learn: 0.0049804	total: 2.81s	remaining: 2.7s
# 102:	learn: 0.0048678	total: 2.84s	remaining: 2.67s
# 103:	learn: 0.0047743	total: 2.87s	remaining: 2.65s
# 104:	learn: 0.0047143	total: 2.9s	remaining: 2.63s
# 105:	learn: 0.0046392	total: 2.93s	remaining: 2.6s
# 106:	learn: 0.0045333	total: 2.96s	remaining: 2.58s
# 107:	learn: 0.0043470	total: 2.99s	remaining: 2.55s
# 108:	learn: 0.0042551	total: 3.02s	remaining: 2.52s
# 109:	learn: 0.0041633	total: 3.05s	remaining: 2.5s
# 110:	learn: 0.0041035	total: 3.08s	remaining: 2.47s
# 111:	learn: 0.0040467	total: 3.11s	remaining: 2.45s
# 112:	learn: 0.0039712	total: 3.14s	remaining: 2.42s
# 113:	learn: 0.0039174	total: 3.17s	remaining: 2.39s
# 114:	learn: 0.0038587	total: 3.2s	remaining: 2.36s
# 115:	learn: 0.0037783	total: 3.22s	remaining: 2.33s
# 116:	learn: 0.0037359	total: 3.25s	remaining: 2.31s
# 117:	learn: 0.0037101	total: 3.27s	remaining: 2.27s
# 118:	learn: 0.0036503	total: 3.3s	remaining: 2.24s
# 119:	learn: 0.0035902	total: 3.32s	remaining: 2.21s
# 120:	learn: 0.0035291	total: 3.35s	remaining: 2.19s
# 121:	learn: 0.0034807	total: 3.38s	remaining: 2.16s
# 122:	learn: 0.0034503	total: 3.41s	remaining: 2.13s
# 123:	learn: 0.0033939	total: 3.43s	remaining: 2.1s
# 124:	learn: 0.0033203	total: 3.46s	remaining: 2.07s
# 125:	learn: 0.0032842	total: 3.48s	remaining: 2.04s
# 126:	learn: 0.0031974	total: 3.5s	remaining: 2.02s
# 127:	learn: 0.0031377	total: 3.53s	remaining: 1.98s
# 128:	learn: 0.0030925	total: 3.55s	remaining: 1.95s
# 129:	learn: 0.0030571	total: 3.58s	remaining: 1.93s
# 130:	learn: 0.0029922	total: 3.61s	remaining: 1.9s
# 131:	learn: 0.0029556	total: 3.63s	remaining: 1.87s
# 132:	learn: 0.0029160	total: 3.66s	remaining: 1.84s
# 133:	learn: 0.0028723	total: 3.68s	remaining: 1.81s
# 134:	learn: 0.0028325	total: 3.71s	remaining: 1.78s
# 135:	learn: 0.0027883	total: 3.73s	remaining: 1.75s
# 136:	learn: 0.0027734	total: 3.76s	remaining: 1.73s
# 137:	learn: 0.0027279	total: 3.79s	remaining: 1.7s
# 138:	learn: 0.0026894	total: 3.81s	remaining: 1.67s
# 139:	learn: 0.0026524	total: 3.84s	remaining: 1.65s
# 140:	learn: 0.0026081	total: 3.87s	remaining: 1.62s
# 141:	learn: 0.0025757	total: 3.89s	remaining: 1.59s
# 142:	learn: 0.0025347	total: 3.92s	remaining: 1.56s
# 143:	learn: 0.0024822	total: 3.95s	remaining: 1.53s
# 144:	learn: 0.0024453	total: 3.97s	remaining: 1.51s
# 145:	learn: 0.0023983	total: 4s	remaining: 1.48s
# 146:	learn: 0.0023712	total: 4.02s	remaining: 1.45s
# 147:	learn: 0.0023048	total: 4.05s	remaining: 1.42s
# 148:	learn: 0.0022771	total: 4.07s	remaining: 1.39s
# 149:	learn: 0.0022452	total: 4.1s	remaining: 1.37s
# 150:	learn: 0.0021929	total: 4.13s	remaining: 1.34s
# 151:	learn: 0.0021676	total: 4.15s	remaining: 1.31s
# 152:	learn: 0.0021296	total: 4.17s	remaining: 1.28s
# 153:	learn: 0.0020920	total: 4.2s	remaining: 1.25s
# 154:	learn: 0.0020688	total: 4.22s	remaining: 1.23s
# 155:	learn: 0.0020045	total: 4.25s	remaining: 1.2s
# 156:	learn: 0.0019685	total: 4.27s	remaining: 1.17s
# 157:	learn: 0.0019393	total: 4.3s	remaining: 1.14s
# 158:	learn: 0.0019178	total: 4.32s	remaining: 1.11s
# 159:	learn: 0.0019001	total: 4.35s	remaining: 1.09s
# 160:	learn: 0.0018832	total: 4.37s	remaining: 1.06s
# 161:	learn: 0.0018386	total: 4.4s	remaining: 1.03s
# 162:	learn: 0.0017918	total: 4.42s	remaining: 1s
# 163:	learn: 0.0017728	total: 4.45s	remaining: 976ms
# 164:	learn: 0.0017496	total: 4.47s	remaining: 949ms
# 165:	learn: 0.0017119	total: 4.5s	remaining: 922ms
# 166:	learn: 0.0016874	total: 4.52s	remaining: 894ms
# 167:	learn: 0.0016685	total: 4.55s	remaining: 867ms
# 168:	learn: 0.0016412	total: 4.57s	remaining: 839ms
# 169:	learn: 0.0016246	total: 4.6s	remaining: 812ms
# 170:	learn: 0.0016044	total: 4.62s	remaining: 784ms
# 171:	learn: 0.0015875	total: 4.65s	remaining: 757ms
# 172:	learn: 0.0015800	total: 4.68s	remaining: 730ms
# 173:	learn: 0.0015451	total: 4.71s	remaining: 703ms
# 174:	learn: 0.0015451	total: 4.73s	remaining: 676ms
# 175:	learn: 0.0015451	total: 4.75s	remaining: 648ms
# 176:	learn: 0.0015451	total: 4.78s	remaining: 621ms
# 177:	learn: 0.0015451	total: 4.8s	remaining: 594ms
# 178:	learn: 0.0015151	total: 4.83s	remaining: 567ms
# 179:	learn: 0.0015018	total: 4.86s	remaining: 540ms
# 180:	learn: 0.0014700	total: 4.88s	remaining: 513ms
# 181:	learn: 0.0014599	total: 4.91s	remaining: 486ms
# 182:	learn: 0.0014433	total: 4.94s	remaining: 459ms
# 183:	learn: 0.0014169	total: 4.96s	remaining: 432ms
# 184:	learn: 0.0014113	total: 4.99s	remaining: 405ms
# 185:	learn: 0.0014114	total: 5.02s	remaining: 378ms
# 186:	learn: 0.0014025	total: 5.05s	remaining: 351ms
# 187:	learn: 0.0013755	total: 5.08s	remaining: 324ms
# 188:	learn: 0.0013478	total: 5.11s	remaining: 297ms
# 189:	learn: 0.0013310	total: 5.13s	remaining: 270ms
# 190:	learn: 0.0013206	total: 5.16s	remaining: 243ms
# 191:	learn: 0.0013088	total: 5.18s	remaining: 216ms
# 192:	learn: 0.0012965	total: 5.21s	remaining: 189ms
# 193:	learn: 0.0012844	total: 5.24s	remaining: 162ms
# 194:	learn: 0.0012757	total: 5.26s	remaining: 135ms
# 195:	learn: 0.0012571	total: 5.29s	remaining: 108ms
# 196:	learn: 0.0012571	total: 5.31s	remaining: 80.9ms
# 197:	learn: 0.0012310	total: 5.34s	remaining: 53.9ms
# 198:	learn: 0.0012129	total: 5.36s	remaining: 27ms
# 199:	learn: 0.0012036	total: 5.39s	remaining: 0us
# Best parameters found for CatBoost:  {'depth': 6, 'l2_leaf_reg': 1, 'learning_rate': 0.1, 'min_data_in_leaf': 1}
# Best F1 score for CatBoost:  0.8097724374517306
# CatBoost model saved to '../models/cb_grid_search.pkl'

# %%
# Load the model
loaded_model_cb = joblib.load('../models/cb_grid_search.pkl')

# Predict probabilities for the test and training sets using the loaded CatBoost model
y_pred_cb_proba = loaded_model_cb.predict_proba(X_test)[:, 1]
y_pred_train_cb_proba = loaded_model_cb.predict_proba(X_train)[:, 1]

# Find the best threshold for F1 score for CatBoost
threshold_cb = find_best_f1_threshold(X_test, y_test, model=loaded_model_cb)

# Calculate the treshold optimizing f1 score for CatBoost
print(f"Best threshold for F1 score for CatBoost: {threshold_cb}")

# Calculate other metrics based on the threshold for CatBoost
print("Results without oversampling for CatBoost:")
results_cb = get_results(y_test, y_pred_cb_proba, y_train, y_pred_train_cb_proba, threshold_cb)

# Plot ROC and PR curves for CatBoost
roc_cb = plot_roc_curve(loaded_model_cb, X_test, y_test)
pr_auc_cb = plot_pr_curve(loaded_model_cb, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9996
# Precision: 0.9425
# Recall: 0.8367
# F1: 0.8865
#
# Metrics for train
# Accuracy: 0.9999
# Precision: 0.9517
# Recall: 1.0000
# F1: 0.9752
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.94      0.84      0.89        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9790
# PR AUC: 0.8743

# %% [markdown]
# **CatBoost with SMOTE**

# %%
# CatBoost model with SMOTE
# Create a new CatBoost model with the calculated scale_pos_weight for SMOTE and ADASYN
model_cb_oversample = cb.CatBoostClassifier(eval_metric='Logloss', random_state=42, scale_pos_weight=scale_pos_weight_oversample, iterations=200,early_stopping_rounds=20)

start = time.time()
grid_cb_smote = GridSearchCV(model_cb_oversample, param_grid=param_grid_cb, cv=3, scoring='f1', n_jobs=-1).fit(X_res, y_res)
end = time.time()
timing_results.append({
    "model": "CatBoost SMOTE",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for CatBoost with SMOTE
print("Best parameters found for CatBoost with SMOTE: ", grid_cb_smote.best_params_)
print("Best F1 score for CatBoost with SMOTE: ", grid_cb_smote.best_score_)

# Save the CatBoost model with SMOTE
joblib.dump(grid_cb_smote, '../models/cb_grid_search_smote.pkl')
print("CatBoost model saved to '../models/cb_grid_search_smote.pkl'")
# Out:
# 0:	learn: 0.5280894	total: 28.4ms	remaining: 5.66s
# 1:	learn: 0.3751507	total: 58.5ms	remaining: 5.79s
# 2:	learn: 0.2802850	total: 87.4ms	remaining: 5.74s
# 3:	learn: 0.2108097	total: 115ms	remaining: 5.61s
# 4:	learn: 0.1771429	total: 142ms	remaining: 5.56s
# 5:	learn: 0.1554994	total: 170ms	remaining: 5.5s
# 6:	learn: 0.1388331	total: 197ms	remaining: 5.42s
# 7:	learn: 0.1265717	total: 224ms	remaining: 5.38s
# 8:	learn: 0.1155715	total: 252ms	remaining: 5.35s
# 9:	learn: 0.1071138	total: 287ms	remaining: 5.46s
# 10:	learn: 0.0994492	total: 315ms	remaining: 5.41s
# 11:	learn: 0.0907636	total: 344ms	remaining: 5.4s
# 12:	learn: 0.0866872	total: 376ms	remaining: 5.41s
# 13:	learn: 0.0820223	total: 404ms	remaining: 5.36s
# 14:	learn: 0.0778267	total: 431ms	remaining: 5.32s
# 15:	learn: 0.0740487	total: 460ms	remaining: 5.29s
# 16:	learn: 0.0705057	total: 501ms	remaining: 5.39s
# 17:	learn: 0.0677582	total: 548ms	remaining: 5.54s
# 18:	learn: 0.0665272	total: 578ms	remaining: 5.5s
# 19:	learn: 0.0648650	total: 605ms	remaining: 5.45s
# 20:	learn: 0.0633106	total: 632ms	remaining: 5.39s
# 21:	learn: 0.0616201	total: 662ms	remaining: 5.36s
# 22:	learn: 0.0594015	total: 692ms	remaining: 5.33s
# 23:	learn: 0.0582371	total: 725ms	remaining: 5.32s
# 24:	learn: 0.0566292	total: 754ms	remaining: 5.28s
# 25:	learn: 0.0546458	total: 780ms	remaining: 5.22s
# 26:	learn: 0.0531814	total: 809ms	remaining: 5.18s
# 27:	learn: 0.0511768	total: 836ms	remaining: 5.14s
# 28:	learn: 0.0492081	total: 865ms	remaining: 5.1s
# 29:	learn: 0.0473668	total: 894ms	remaining: 5.07s
# 30:	learn: 0.0463104	total: 923ms	remaining: 5.03s
# 31:	learn: 0.0449012	total: 951ms	remaining: 4.99s
# 32:	learn: 0.0436246	total: 978ms	remaining: 4.95s
# 33:	learn: 0.0418998	total: 1.01s	remaining: 4.91s
# 34:	learn: 0.0409281	total: 1.03s	remaining: 4.88s
# 35:	learn: 0.0401502	total: 1.06s	remaining: 4.84s
# 36:	learn: 0.0385529	total: 1.09s	remaining: 4.81s
# 37:	learn: 0.0375420	total: 1.12s	remaining: 4.79s
# 38:	learn: 0.0364475	total: 1.16s	remaining: 4.77s
# 39:	learn: 0.0355526	total: 1.18s	remaining: 4.74s
# 40:	learn: 0.0334588	total: 1.21s	remaining: 4.7s
# 41:	learn: 0.0326667	total: 1.24s	remaining: 4.67s
# 42:	learn: 0.0316890	total: 1.27s	remaining: 4.64s
# 43:	learn: 0.0308628	total: 1.3s	remaining: 4.61s
# 44:	learn: 0.0296430	total: 1.33s	remaining: 4.58s
# 45:	learn: 0.0283444	total: 1.36s	remaining: 4.56s
# 46:	learn: 0.0277107	total: 1.39s	remaining: 4.53s
# 47:	learn: 0.0270182	total: 1.42s	remaining: 4.49s
# 48:	learn: 0.0265493	total: 1.45s	remaining: 4.46s
# 49:	learn: 0.0259348	total: 1.47s	remaining: 4.42s
# 50:	learn: 0.0250920	total: 1.5s	remaining: 4.39s
# 51:	learn: 0.0241186	total: 1.53s	remaining: 4.35s
# 52:	learn: 0.0234108	total: 1.56s	remaining: 4.33s
# 53:	learn: 0.0227387	total: 1.59s	remaining: 4.29s
# 54:	learn: 0.0221021	total: 1.61s	remaining: 4.26s
# 55:	learn: 0.0216792	total: 1.64s	remaining: 4.22s
# 56:	learn: 0.0208948	total: 1.67s	remaining: 4.18s
# 57:	learn: 0.0205367	total: 1.69s	remaining: 4.15s
# 58:	learn: 0.0200786	total: 1.73s	remaining: 4.12s
# 59:	learn: 0.0196722	total: 1.75s	remaining: 4.09s
# 60:	learn: 0.0190428	total: 1.78s	remaining: 4.05s
# 61:	learn: 0.0186971	total: 1.81s	remaining: 4.02s
# 62:	learn: 0.0182633	total: 1.84s	remaining: 3.99s
# 63:	learn: 0.0179725	total: 1.87s	remaining: 3.97s
# 64:	learn: 0.0175550	total: 1.9s	remaining: 3.94s
# 65:	learn: 0.0171136	total: 1.93s	remaining: 3.91s
# 66:	learn: 0.0166935	total: 1.96s	remaining: 3.89s
# 67:	learn: 0.0164046	total: 1.99s	remaining: 3.86s
# 68:	learn: 0.0161157	total: 2.02s	remaining: 3.83s
# 69:	learn: 0.0155261	total: 2.05s	remaining: 3.8s
# 70:	learn: 0.0150288	total: 2.08s	remaining: 3.77s
# 71:	learn: 0.0148255	total: 2.1s	remaining: 3.74s
# 72:	learn: 0.0145915	total: 2.13s	remaining: 3.7s
# 73:	learn: 0.0144591	total: 2.16s	remaining: 3.67s
# 74:	learn: 0.0140918	total: 2.19s	remaining: 3.64s
# 75:	learn: 0.0137351	total: 2.21s	remaining: 3.61s
# 76:	learn: 0.0134851	total: 2.24s	remaining: 3.58s
# 77:	learn: 0.0130535	total: 2.27s	remaining: 3.54s
# 78:	learn: 0.0126603	total: 2.3s	remaining: 3.52s
# 79:	learn: 0.0124717	total: 2.32s	remaining: 3.48s
# 80:	learn: 0.0119425	total: 2.35s	remaining: 3.45s
# 81:	learn: 0.0117876	total: 2.38s	remaining: 3.42s
# 82:	learn: 0.0115564	total: 2.4s	remaining: 3.39s
# 83:	learn: 0.0113834	total: 2.43s	remaining: 3.36s
# 84:	learn: 0.0112624	total: 2.46s	remaining: 3.33s
# 85:	learn: 0.0110739	total: 2.49s	remaining: 3.3s
# 86:	learn: 0.0108258	total: 2.51s	remaining: 3.27s
# 87:	learn: 0.0105960	total: 2.54s	remaining: 3.23s
# 88:	learn: 0.0103572	total: 2.57s	remaining: 3.2s
# 89:	learn: 0.0102647	total: 2.6s	remaining: 3.17s
# 90:	learn: 0.0100178	total: 2.63s	remaining: 3.15s
# 91:	learn: 0.0098900	total: 2.65s	remaining: 3.11s
# 92:	learn: 0.0097144	total: 2.68s	remaining: 3.08s
# 93:	learn: 0.0095531	total: 2.71s	remaining: 3.06s
# 94:	learn: 0.0094066	total: 2.74s	remaining: 3.02s
# 95:	learn: 0.0092961	total: 2.76s	remaining: 2.99s
# 96:	learn: 0.0090880	total: 2.79s	remaining: 2.96s
# 97:	learn: 0.0089364	total: 2.81s	remaining: 2.93s
# 98:	learn: 0.0087626	total: 2.84s	remaining: 2.9s
# 99:	learn: 0.0086049	total: 2.87s	remaining: 2.87s
# 100:	learn: 0.0085219	total: 2.9s	remaining: 2.84s
# 101:	learn: 0.0084577	total: 2.93s	remaining: 2.81s
# 102:	learn: 0.0082613	total: 2.95s	remaining: 2.78s
# 103:	learn: 0.0081425	total: 2.98s	remaining: 2.75s
# 104:	learn: 0.0080251	total: 3.02s	remaining: 2.73s
# 105:	learn: 0.0078878	total: 3.05s	remaining: 2.7s
# 106:	learn: 0.0077046	total: 3.07s	remaining: 2.67s
# 107:	learn: 0.0076329	total: 3.1s	remaining: 2.65s
# 108:	learn: 0.0075681	total: 3.13s	remaining: 2.62s
# 109:	learn: 0.0074841	total: 3.16s	remaining: 2.59s
# 110:	learn: 0.0074187	total: 3.19s	remaining: 2.56s
# 111:	learn: 0.0073224	total: 3.22s	remaining: 2.53s
# 112:	learn: 0.0071686	total: 3.25s	remaining: 2.5s
# 113:	learn: 0.0070271	total: 3.28s	remaining: 2.48s
# 114:	learn: 0.0069242	total: 3.31s	remaining: 2.44s
# 115:	learn: 0.0068119	total: 3.33s	remaining: 2.41s
# 116:	learn: 0.0066855	total: 3.36s	remaining: 2.38s
# 117:	learn: 0.0064574	total: 3.39s	remaining: 2.35s
# 118:	learn: 0.0062171	total: 3.41s	remaining: 2.32s
# 119:	learn: 0.0061496	total: 3.44s	remaining: 2.29s
# 120:	learn: 0.0060464	total: 3.46s	remaining: 2.26s
# 121:	learn: 0.0059594	total: 3.49s	remaining: 2.23s
# 122:	learn: 0.0058806	total: 3.51s	remaining: 2.2s
# 123:	learn: 0.0058149	total: 3.54s	remaining: 2.17s
# 124:	learn: 0.0057238	total: 3.57s	remaining: 2.14s
# 125:	learn: 0.0056155	total: 3.59s	remaining: 2.11s
# 126:	learn: 0.0055687	total: 3.62s	remaining: 2.08s
# 127:	learn: 0.0054388	total: 3.65s	remaining: 2.05s
# 128:	learn: 0.0053279	total: 3.68s	remaining: 2.02s
# 129:	learn: 0.0052745	total: 3.7s	remaining: 1.99s
# 130:	learn: 0.0052095	total: 3.73s	remaining: 1.97s
# 131:	learn: 0.0051418	total: 3.76s	remaining: 1.94s
# 132:	learn: 0.0050856	total: 3.78s	remaining: 1.91s
# 133:	learn: 0.0050197	total: 3.81s	remaining: 1.88s
# 134:	learn: 0.0049871	total: 3.84s	remaining: 1.85s
# 135:	learn: 0.0048914	total: 3.86s	remaining: 1.82s
# 136:	learn: 0.0048285	total: 3.89s	remaining: 1.79s
# 137:	learn: 0.0047541	total: 3.91s	remaining: 1.76s
# 138:	learn: 0.0047101	total: 3.94s	remaining: 1.73s
# 139:	learn: 0.0046644	total: 3.97s	remaining: 1.7s
# 140:	learn: 0.0046153	total: 3.99s	remaining: 1.67s
# 141:	learn: 0.0045965	total: 4.02s	remaining: 1.64s
# 142:	learn: 0.0045404	total: 4.05s	remaining: 1.61s
# 143:	learn: 0.0045085	total: 4.07s	remaining: 1.58s
# 144:	learn: 0.0044282	total: 4.1s	remaining: 1.55s
# 145:	learn: 0.0043770	total: 4.12s	remaining: 1.52s
# 146:	learn: 0.0043348	total: 4.15s	remaining: 1.5s
# 147:	learn: 0.0042120	total: 4.18s	remaining: 1.47s
# 148:	learn: 0.0041427	total: 4.21s	remaining: 1.44s
# 149:	learn: 0.0040420	total: 4.23s	remaining: 1.41s
# 150:	learn: 0.0040100	total: 4.26s	remaining: 1.38s
# 151:	learn: 0.0039346	total: 4.29s	remaining: 1.35s
# 152:	learn: 0.0039142	total: 4.31s	remaining: 1.32s
# 153:	learn: 0.0038893	total: 4.34s	remaining: 1.29s
# 154:	learn: 0.0038338	total: 4.37s	remaining: 1.27s
# 155:	learn: 0.0037796	total: 4.39s	remaining: 1.24s
# 156:	learn: 0.0037103	total: 4.42s	remaining: 1.21s
# 157:	learn: 0.0036478	total: 4.44s	remaining: 1.18s
# 158:	learn: 0.0036249	total: 4.47s	remaining: 1.15s
# 159:	learn: 0.0035837	total: 4.5s	remaining: 1.12s
# 160:	learn: 0.0035582	total: 4.52s	remaining: 1.09s
# 161:	learn: 0.0035160	total: 4.55s	remaining: 1.07s
# 162:	learn: 0.0034718	total: 4.58s	remaining: 1.04s
# 163:	learn: 0.0034232	total: 4.61s	remaining: 1.01s
# 164:	learn: 0.0033828	total: 4.64s	remaining: 984ms
# 165:	learn: 0.0033441	total: 4.67s	remaining: 956ms
# 166:	learn: 0.0033126	total: 4.69s	remaining: 927ms
# 167:	learn: 0.0032825	total: 4.72s	remaining: 898ms
# 168:	learn: 0.0032564	total: 4.74s	remaining: 870ms
# 169:	learn: 0.0032136	total: 4.77s	remaining: 841ms
# 170:	learn: 0.0031764	total: 4.79s	remaining: 813ms
# 171:	learn: 0.0031450	total: 4.82s	remaining: 785ms
# 172:	learn: 0.0031108	total: 4.84s	remaining: 756ms
# 173:	learn: 0.0030820	total: 4.87s	remaining: 728ms
# 174:	learn: 0.0030549	total: 4.9s	remaining: 700ms
# 175:	learn: 0.0030232	total: 4.93s	remaining: 673ms
# 176:	learn: 0.0029593	total: 4.96s	remaining: 644ms
# 177:	learn: 0.0029375	total: 4.99s	remaining: 617ms
# 178:	learn: 0.0029121	total: 5.01s	remaining: 588ms
# 179:	learn: 0.0028853	total: 5.04s	remaining: 560ms
# 180:	learn: 0.0028663	total: 5.07s	remaining: 532ms
# 181:	learn: 0.0028324	total: 5.09s	remaining: 504ms
# 182:	learn: 0.0027948	total: 5.12s	remaining: 476ms
# 183:	learn: 0.0027681	total: 5.15s	remaining: 448ms
# 184:	learn: 0.0027401	total: 5.17s	remaining: 420ms
# 185:	learn: 0.0027092	total: 5.2s	remaining: 392ms
# 186:	learn: 0.0026922	total: 5.23s	remaining: 364ms
# 187:	learn: 0.0026514	total: 5.25s	remaining: 335ms
# 188:	learn: 0.0026181	total: 5.28s	remaining: 307ms
# 189:	learn: 0.0025917	total: 5.3s	remaining: 279ms
# 190:	learn: 0.0025675	total: 5.33s	remaining: 251ms
# 191:	learn: 0.0025261	total: 5.36s	remaining: 223ms
# 192:	learn: 0.0025086	total: 5.39s	remaining: 195ms
# 193:	learn: 0.0024824	total: 5.41s	remaining: 167ms
# 194:	learn: 0.0024501	total: 5.44s	remaining: 140ms
# 195:	learn: 0.0024337	total: 5.46s	remaining: 112ms
# 196:	learn: 0.0024154	total: 5.49s	remaining: 83.6ms
# 197:	learn: 0.0023877	total: 5.52s	remaining: 55.8ms
# 198:	learn: 0.0023708	total: 5.55s	remaining: 27.9ms
# 199:	learn: 0.0023494	total: 5.58s	remaining: 0us
# Best parameters found for CatBoost with SMOTE:  {'depth': 6, 'l2_leaf_reg': 1, 'learning_rate': 0.1, 'min_data_in_leaf': 1}
# Best F1 score for CatBoost with SMOTE:  0.9589165012318507
# CatBoost model saved to '../models/cb_grid_search_smote.pkl'

# %%
# Load the model with SMOTE
loaded_model_cb_smote = joblib.load('../models/cb_grid_search_smote.pkl')

# Predict probabilities for the test and training sets using the loaded CatBoost model with SMOTE
y_pred_cb_smote_proba = loaded_model_cb_smote.predict_proba(X_test)[:, 1]
y_pred_train_cb_smote_proba = loaded_model_cb_smote.predict_proba(X_res)[:, 1]

# Find the best threshold for F1 score for CatBoost with SMOTE
threshold_cb_smote = find_best_f1_threshold(X_test, y_test, model=loaded_model_cb_smote)

# Calculate the treshold optimizing f1 score for CatBoost with SMOTE
print(f"Best threshold for F1 score for CatBoost with SMOTE: {threshold_cb_smote}")

# Calculate other metrics based on the threshold for CatBoost with SMOTE
print("Results with SMOTE for CatBoost:")
results_cb_smote = get_results(y_test, y_pred_cb_smote_proba, y_res, y_pred_train_cb_smote_proba, threshold_cb_smote)

# Plot ROC and PR curves for CatBoost with SMOTE
roc_cb_smote = plot_roc_curve(loaded_model_cb_smote, X_test, y_test)
pr_auc_cb_smote = plot_pr_curve(loaded_model_cb_smote, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9995
# Precision: 0.8542
# Recall: 0.8367
# F1: 0.8454
#
# Metrics for train
# Accuracy: 0.9998
# Precision: 0.9874
# Recall: 0.9960
# F1: 0.9917
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.85      0.84      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.92      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9777
# PR AUC: 0.8614

# %% [markdown]
# **CatBoost with ADYSYN**

# %%
# CatBoost model with ADASYN
# Create a new CatBoost model with the calculated earilier scale_pos_weight for ADASYN
start = time.time()
grid_cb_adasyn = GridSearchCV(model_cb_oversample, param_grid=param_grid_cb, cv=3, scoring='f1', n_jobs=-1).fit(X_res_adasyn, y_res_adasyn)
end = time.time()
timing_results.append({
    "model": "CatBoost ADASYN",
    "training time (sec)": round(end - start, 2)
})

# Print the best parameters and best score for CatBoost with ADASYN
print("Best parameters found for CatBoost with ADASYN: ", grid_cb_adasyn.best_params_)
print("Best F1 score for CatBoost with ADASYN: ", grid_cb_adasyn.best_score_)

# Save the CatBoost model with ADASYN
joblib.dump(grid_cb_adasyn, '../models/cb_grid_search_adasyn.pkl')
print("CatBoost model saved to '../models/cb_grid_search_adasyn.pkl'")
# Out:
# 0:	learn: 0.5466852	total: 29.7ms	remaining: 5.91s
# 1:	learn: 0.4307640	total: 67.2ms	remaining: 6.66s
# 2:	learn: 0.3572511	total: 109ms	remaining: 7.18s
# 3:	learn: 0.3043303	total: 135ms	remaining: 6.61s
# 4:	learn: 0.2707955	total: 160ms	remaining: 6.23s
# 5:	learn: 0.2377938	total: 186ms	remaining: 6.03s
# 6:	learn: 0.2161382	total: 216ms	remaining: 5.95s
# 7:	learn: 0.1921217	total: 245ms	remaining: 5.88s
# 8:	learn: 0.1760793	total: 279ms	remaining: 5.92s
# 9:	learn: 0.1640233	total: 305ms	remaining: 5.79s
# 10:	learn: 0.1543385	total: 331ms	remaining: 5.68s
# 11:	learn: 0.1468827	total: 356ms	remaining: 5.57s
# 12:	learn: 0.1379561	total: 381ms	remaining: 5.48s
# 13:	learn: 0.1311089	total: 405ms	remaining: 5.38s
# 14:	learn: 0.1258337	total: 428ms	remaining: 5.28s
# 15:	learn: 0.1195503	total: 456ms	remaining: 5.24s
# 16:	learn: 0.1145271	total: 480ms	remaining: 5.17s
# 17:	learn: 0.1102272	total: 506ms	remaining: 5.12s
# 18:	learn: 0.1062570	total: 532ms	remaining: 5.06s
# 19:	learn: 0.1013262	total: 557ms	remaining: 5.01s
# 20:	learn: 0.0984839	total: 582ms	remaining: 4.96s
# 21:	learn: 0.0961772	total: 607ms	remaining: 4.91s
# 22:	learn: 0.0934908	total: 631ms	remaining: 4.85s
# 23:	learn: 0.0913448	total: 656ms	remaining: 4.81s
# 24:	learn: 0.0870235	total: 680ms	remaining: 4.76s
# 25:	learn: 0.0845080	total: 708ms	remaining: 4.74s
# 26:	learn: 0.0818390	total: 732ms	remaining: 4.69s
# 27:	learn: 0.0796984	total: 754ms	remaining: 4.63s
# 28:	learn: 0.0774198	total: 777ms	remaining: 4.58s
# 29:	learn: 0.0745493	total: 799ms	remaining: 4.53s
# 30:	learn: 0.0732011	total: 825ms	remaining: 4.5s
# 31:	learn: 0.0718302	total: 851ms	remaining: 4.47s
# 32:	learn: 0.0702978	total: 874ms	remaining: 4.42s
# 33:	learn: 0.0689210	total: 901ms	remaining: 4.4s
# 34:	learn: 0.0674028	total: 927ms	remaining: 4.37s
# 35:	learn: 0.0653598	total: 953ms	remaining: 4.34s
# 36:	learn: 0.0639178	total: 979ms	remaining: 4.31s
# 37:	learn: 0.0624758	total: 1.01s	remaining: 4.29s
# 38:	learn: 0.0608104	total: 1.03s	remaining: 4.27s
# 39:	learn: 0.0587204	total: 1.06s	remaining: 4.25s
# 40:	learn: 0.0574755	total: 1.09s	remaining: 4.23s
# 41:	learn: 0.0561595	total: 1.13s	remaining: 4.27s
# 42:	learn: 0.0552784	total: 1.17s	remaining: 4.27s
# 43:	learn: 0.0539879	total: 1.2s	remaining: 4.25s
# 44:	learn: 0.0525829	total: 1.22s	remaining: 4.22s
# 45:	learn: 0.0516965	total: 1.25s	remaining: 4.2s
# 46:	learn: 0.0506162	total: 1.29s	remaining: 4.2s
# 47:	learn: 0.0497664	total: 1.32s	remaining: 4.17s
# 48:	learn: 0.0486593	total: 1.35s	remaining: 4.15s
# 49:	learn: 0.0473913	total: 1.38s	remaining: 4.15s
# 50:	learn: 0.0460758	total: 1.41s	remaining: 4.13s
# 51:	learn: 0.0445507	total: 1.44s	remaining: 4.11s
# 52:	learn: 0.0436887	total: 1.48s	remaining: 4.1s
# 53:	learn: 0.0431145	total: 1.51s	remaining: 4.08s
# 54:	learn: 0.0420804	total: 1.54s	remaining: 4.06s
# 55:	learn: 0.0407187	total: 1.57s	remaining: 4.05s
# 56:	learn: 0.0397821	total: 1.61s	remaining: 4.04s
# 57:	learn: 0.0388051	total: 1.65s	remaining: 4.04s
# 58:	learn: 0.0381421	total: 1.68s	remaining: 4.03s
# 59:	learn: 0.0372052	total: 1.71s	remaining: 3.99s
# 60:	learn: 0.0364384	total: 1.73s	remaining: 3.95s
# 61:	learn: 0.0357536	total: 1.76s	remaining: 3.92s
# 62:	learn: 0.0346474	total: 1.78s	remaining: 3.88s
# 63:	learn: 0.0340664	total: 1.81s	remaining: 3.84s
# 64:	learn: 0.0331672	total: 1.83s	remaining: 3.8s
# 65:	learn: 0.0325820	total: 1.86s	remaining: 3.77s
# 66:	learn: 0.0319040	total: 1.88s	remaining: 3.74s
# 67:	learn: 0.0312992	total: 1.91s	remaining: 3.7s
# 68:	learn: 0.0302572	total: 1.93s	remaining: 3.67s
# 69:	learn: 0.0295556	total: 1.96s	remaining: 3.64s
# 70:	learn: 0.0290828	total: 1.99s	remaining: 3.61s
# 71:	learn: 0.0282965	total: 2.01s	remaining: 3.58s
# 72:	learn: 0.0279473	total: 2.04s	remaining: 3.56s
# 73:	learn: 0.0270462	total: 2.07s	remaining: 3.52s
# 74:	learn: 0.0261301	total: 2.1s	remaining: 3.5s
# 75:	learn: 0.0256552	total: 2.13s	remaining: 3.47s
# 76:	learn: 0.0251465	total: 2.15s	remaining: 3.44s
# 77:	learn: 0.0245094	total: 2.18s	remaining: 3.42s
# 78:	learn: 0.0240574	total: 2.21s	remaining: 3.39s
# 79:	learn: 0.0236127	total: 2.25s	remaining: 3.38s
# 80:	learn: 0.0231673	total: 2.28s	remaining: 3.35s
# 81:	learn: 0.0228621	total: 2.31s	remaining: 3.32s
# 82:	learn: 0.0223810	total: 2.33s	remaining: 3.29s
# 83:	learn: 0.0219590	total: 2.36s	remaining: 3.26s
# 84:	learn: 0.0215271	total: 2.38s	remaining: 3.22s
# 85:	learn: 0.0211776	total: 2.41s	remaining: 3.19s
# 86:	learn: 0.0207421	total: 2.43s	remaining: 3.16s
# 87:	learn: 0.0204729	total: 2.46s	remaining: 3.13s
# 88:	learn: 0.0201497	total: 2.49s	remaining: 3.1s
# 89:	learn: 0.0198669	total: 2.52s	remaining: 3.08s
# 90:	learn: 0.0192653	total: 2.54s	remaining: 3.04s
# 91:	learn: 0.0189516	total: 2.57s	remaining: 3.01s
# 92:	learn: 0.0186089	total: 2.59s	remaining: 2.98s
# 93:	learn: 0.0182552	total: 2.61s	remaining: 2.95s
# 94:	learn: 0.0178310	total: 2.64s	remaining: 2.91s
# 95:	learn: 0.0175313	total: 2.66s	remaining: 2.88s
# 96:	learn: 0.0173792	total: 2.68s	remaining: 2.85s
# 97:	learn: 0.0171088	total: 2.71s	remaining: 2.82s
# 98:	learn: 0.0168592	total: 2.73s	remaining: 2.79s
# 99:	learn: 0.0166658	total: 2.76s	remaining: 2.76s
# 100:	learn: 0.0164086	total: 2.78s	remaining: 2.73s
# 101:	learn: 0.0160823	total: 2.81s	remaining: 2.69s
# 102:	learn: 0.0157956	total: 2.83s	remaining: 2.66s
# 103:	learn: 0.0154174	total: 2.85s	remaining: 2.63s
# 104:	learn: 0.0152626	total: 2.88s	remaining: 2.61s
# 105:	learn: 0.0150731	total: 2.91s	remaining: 2.58s
# 106:	learn: 0.0148672	total: 2.93s	remaining: 2.55s
# 107:	learn: 0.0147044	total: 2.96s	remaining: 2.52s
# 108:	learn: 0.0145550	total: 2.98s	remaining: 2.49s
# 109:	learn: 0.0144112	total: 3.01s	remaining: 2.46s
# 110:	learn: 0.0141078	total: 3.03s	remaining: 2.43s
# 111:	learn: 0.0138877	total: 3.06s	remaining: 2.4s
# 112:	learn: 0.0136439	total: 3.08s	remaining: 2.37s
# 113:	learn: 0.0134561	total: 3.1s	remaining: 2.34s
# 114:	learn: 0.0132236	total: 3.14s	remaining: 2.32s
# 115:	learn: 0.0130626	total: 3.17s	remaining: 2.29s
# 116:	learn: 0.0128819	total: 3.19s	remaining: 2.27s
# 117:	learn: 0.0125874	total: 3.22s	remaining: 2.23s
# 118:	learn: 0.0122978	total: 3.24s	remaining: 2.21s
# 119:	learn: 0.0121416	total: 3.26s	remaining: 2.18s
# 120:	learn: 0.0120017	total: 3.29s	remaining: 2.15s
# 121:	learn: 0.0116285	total: 3.32s	remaining: 2.12s
# 122:	learn: 0.0114579	total: 3.34s	remaining: 2.09s
# 123:	learn: 0.0112745	total: 3.37s	remaining: 2.06s
# 124:	learn: 0.0111502	total: 3.39s	remaining: 2.04s
# 125:	learn: 0.0110387	total: 3.42s	remaining: 2.01s
# 126:	learn: 0.0108824	total: 3.44s	remaining: 1.98s
# 127:	learn: 0.0107678	total: 3.47s	remaining: 1.95s
# 128:	learn: 0.0106492	total: 3.5s	remaining: 1.92s
# 129:	learn: 0.0104575	total: 3.52s	remaining: 1.9s
# 130:	learn: 0.0103190	total: 3.54s	remaining: 1.87s
# 131:	learn: 0.0101197	total: 3.57s	remaining: 1.84s
# 132:	learn: 0.0099749	total: 3.59s	remaining: 1.81s
# 133:	learn: 0.0099043	total: 3.62s	remaining: 1.78s
# 134:	learn: 0.0097157	total: 3.64s	remaining: 1.75s
# 135:	learn: 0.0095421	total: 3.67s	remaining: 1.72s
# 136:	learn: 0.0094061	total: 3.69s	remaining: 1.7s
# 137:	learn: 0.0092696	total: 3.71s	remaining: 1.67s
# 138:	learn: 0.0091798	total: 3.74s	remaining: 1.64s
# 139:	learn: 0.0089852	total: 3.76s	remaining: 1.61s
# 140:	learn: 0.0088448	total: 3.79s	remaining: 1.58s
# 141:	learn: 0.0087626	total: 3.82s	remaining: 1.56s
# 142:	learn: 0.0086362	total: 3.84s	remaining: 1.53s
# 143:	learn: 0.0085178	total: 3.87s	remaining: 1.51s
# 144:	learn: 0.0084312	total: 3.91s	remaining: 1.48s
# 145:	learn: 0.0082357	total: 3.94s	remaining: 1.46s
# 146:	learn: 0.0081447	total: 3.96s	remaining: 1.43s
# 147:	learn: 0.0079861	total: 3.98s	remaining: 1.4s
# 148:	learn: 0.0079139	total: 4s	remaining: 1.37s
# 149:	learn: 0.0077645	total: 4.03s	remaining: 1.34s
# 150:	learn: 0.0076915	total: 4.05s	remaining: 1.31s
# 151:	learn: 0.0075987	total: 4.08s	remaining: 1.29s
# 152:	learn: 0.0075389	total: 4.1s	remaining: 1.26s
# 153:	learn: 0.0074139	total: 4.13s	remaining: 1.23s
# 154:	learn: 0.0073230	total: 4.15s	remaining: 1.21s
# 155:	learn: 0.0072794	total: 4.18s	remaining: 1.18s
# 156:	learn: 0.0072297	total: 4.2s	remaining: 1.15s
# 157:	learn: 0.0071077	total: 4.22s	remaining: 1.12s
# 158:	learn: 0.0070543	total: 4.25s	remaining: 1.1s
# 159:	learn: 0.0069338	total: 4.27s	remaining: 1.07s
# 160:	learn: 0.0068586	total: 4.3s	remaining: 1.04s
# 161:	learn: 0.0068039	total: 4.32s	remaining: 1.01s
# 162:	learn: 0.0066583	total: 4.35s	remaining: 987ms
# 163:	learn: 0.0065284	total: 4.37s	remaining: 960ms
# 164:	learn: 0.0064318	total: 4.4s	remaining: 933ms
# 165:	learn: 0.0063612	total: 4.42s	remaining: 906ms
# 166:	learn: 0.0062986	total: 4.45s	remaining: 880ms
# 167:	learn: 0.0062324	total: 4.47s	remaining: 853ms
# 168:	learn: 0.0061634	total: 4.5s	remaining: 825ms
# 169:	learn: 0.0061130	total: 4.54s	remaining: 800ms
# 170:	learn: 0.0060791	total: 4.56s	remaining: 773ms
# 171:	learn: 0.0060595	total: 4.58s	remaining: 746ms
# 172:	learn: 0.0060439	total: 4.61s	remaining: 720ms
# 173:	learn: 0.0059307	total: 4.63s	remaining: 693ms
# 174:	learn: 0.0058576	total: 4.66s	remaining: 666ms
# 175:	learn: 0.0058111	total: 4.68s	remaining: 639ms
# 176:	learn: 0.0057295	total: 4.71s	remaining: 612ms
# 177:	learn: 0.0056613	total: 4.74s	remaining: 586ms
# 178:	learn: 0.0056171	total: 4.76s	remaining: 559ms
# 179:	learn: 0.0055500	total: 4.78s	remaining: 532ms
# 180:	learn: 0.0054425	total: 4.82s	remaining: 506ms
# 181:	learn: 0.0053848	total: 4.84s	remaining: 479ms
# 182:	learn: 0.0053594	total: 4.87s	remaining: 453ms
# 183:	learn: 0.0053443	total: 4.9s	remaining: 426ms
# 184:	learn: 0.0053129	total: 4.92s	remaining: 399ms
# 185:	learn: 0.0052689	total: 4.95s	remaining: 373ms
# 186:	learn: 0.0052373	total: 4.98s	remaining: 346ms
# 187:	learn: 0.0051738	total: 5s	remaining: 319ms
# 188:	learn: 0.0051079	total: 5.03s	remaining: 293ms
# 189:	learn: 0.0050558	total: 5.07s	remaining: 267ms
# 190:	learn: 0.0050370	total: 5.11s	remaining: 241ms
# 191:	learn: 0.0050019	total: 5.13s	remaining: 214ms
# 192:	learn: 0.0049175	total: 5.15s	remaining: 187ms
# 193:	learn: 0.0048818	total: 5.18s	remaining: 160ms
# 194:	learn: 0.0048286	total: 5.2s	remaining: 133ms
# 195:	learn: 0.0047905	total: 5.23s	remaining: 107ms
# 196:	learn: 0.0047595	total: 5.25s	remaining: 79.9ms
# 197:	learn: 0.0046691	total: 5.28s	remaining: 53.3ms
# 198:	learn: 0.0046380	total: 5.3s	remaining: 26.6ms
# 199:	learn: 0.0046059	total: 5.33s	remaining: 0us
# Best parameters found for CatBoost with ADASYN:  {'depth': 6, 'l2_leaf_reg': 3, 'learning_rate': 0.1, 'min_data_in_leaf': 1}
# Best F1 score for CatBoost with ADASYN:  0.9249842780696603
# CatBoost model saved to '../models/cb_grid_search_adasyn.pkl'

# %%
# Load the model with ADASYN
loaded_model_cb_adasyn = joblib.load('../models/cb_grid_search_adasyn.pkl')

# Predict probabilities for the test and training sets using the loaded CatBoost model with ADASYN
y_pred_cb_adasyn_proba = loaded_model_cb_adasyn.predict_proba(X_test)[:, 1]
y_pred_train_cb_adasyn_proba = loaded_model_cb_adasyn.predict_proba(X_res_adasyn)[:, 1]

# Find the best threshold for F1 score for CatBoost with ADASYN
threshold_cb_adasyn = find_best_f1_threshold(X_test, y_test, model=loaded_model_cb_adasyn)

# Calculate the treshold optimizing f1 score for CatBoost with ADASYN
print(f"Best threshold for F1 score for CatBoost with ADASYN: {threshold_cb_adasyn}")

# Calculate other metrics based on the threshold for CatBoost with ADASYN
print("Results with ADASYN for CatBoost:")
results_cb_adasyn = get_results(y_test, y_pred_cb_adasyn_proba, y_res_adasyn, y_pred_train_cb_adasyn_proba, threshold_cb_adasyn)

# Plot ROC and PR curves for CatBoost with ADASYN
roc_cb_adasyn = plot_roc_curve(loaded_model_cb_adasyn, X_test, y_test)
pr_auc_cb_adasyn = plot_pr_curve(loaded_model_cb_adasyn, X_test, y_test)
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Metrics for test
# Accuracy: 0.9995
# Precision: 0.8696
# Recall: 0.8163
# F1: 0.8421
#
# Metrics for train
# Accuracy: 0.9986
# Precision: 0.9856
# Recall: 0.8771
# F1: 0.9282
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.87      0.82      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962
# AUC: 0.9777
# PR AUC: 0.8482

# %% [markdown]
# # Creating a Summary
#
# To compare model performance across different data preprocessing strategies (Original, SMOTE, ADASYN), we compile the results into a summary table. This table includes the following key evaluation metrics for each model:
#
# - **Accuracy**: Overall correctness of the model’s predictions.
# - **F1-score**: Harmonic mean of precision and recall; a crucial metric for imbalanced datasets.
# - **Precision** and **Recall**: Indicate how well the model identifies positive cases (fraud).
# - **ROC AUC** and **PR AUC**: Reflect the model’s ability to distinguish between classes, especially under class imbalance.
# - **Training Time**: Total time taken to train each model, providing insight into computational efficiency.
#
# This summary enables a well-rounded comparison, helping to:
# - Identify the best-performing model,
# - Evaluate the impact of oversampling (SMOTE and ADASYN),
# - Balance predictive performance with computational cost.

# %%
# Create a DataFrame to summarize the timing results
df_times = pd.DataFrame(timing_results)
display(df_times)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_times = pd.DataFrame(timing_results)
#       2 display(df_times)
#
# NameError: name 'timing_results' is not defined

# %%
# Create a DataFrame to store all results

# Merge timing results with evaluation metrics
# First, create the results DataFrame as before
results_df = pd.DataFrame({
    'Model': ['RandomForest', 'RandomForest SMOTE', 'RandomForest ADASYN',
              'XGBoost', 'XGBoost SMOTE', 'XGBoost ADASYN',
              'CatBoost', 'CatBoost SMOTE', 'CatBoost ADASYN'],
    'Accuracy': [
        results_rf['test']['accuracy'], results_rf_smote['test']['accuracy'], results_rf_adysyn['test']['accuracy'],
        results_xgb['test']['accuracy'], results_xgb_smote['test']['accuracy'], results_xgb_adasyn['test']['accuracy'],
        results_cb['test']['accuracy'], results_cb_smote['test']['accuracy'], results_cb_adasyn['test']['accuracy'],
    ], 
    'F1 Score': [
        results_rf['test']['f1'], results_rf_smote['test']['f1'], results_rf_adysyn['test']['f1'],
        results_xgb['test']['f1'], results_xgb_smote['test']['f1'], results_xgb_adasyn['test']['f1'],
        results_cb['test']['f1'], results_cb_smote['test']['f1'], results_cb_adasyn['test']['f1']
    ],
    'Precision': [
        results_rf['test']['precision'], results_rf_smote['test']['precision'], results_rf_adysyn['test']['precision'],
        results_xgb['test']['precision'], results_xgb_smote['test']['precision'], results_xgb_adasyn['test']['precision'],
        results_cb['test']['precision'], results_cb_smote['test']['precision'], results_cb_adasyn['test']['precision']
    ],
    'Recall': [
        results_rf['test']['recall'], results_rf_smote['test']['recall'], results_rf_adysyn['test']['recall'],
        results_xgb['test']['recall'], results_xgb_smote['test']['recall'], results_xgb_adasyn['test']['recall'],
        results_cb['test']['recall'], results_cb_smote['test']['recall'], results_cb_adasyn['test']['recall']
    ],
    'ROC AUC': [
        roc_rf, roc_rf_smote, roc_rf_adasyn,
        roc_xgb, roc_xgb_smote, roc_xgb_adasyn,
        roc_cb, roc_cb_smote, roc_cb_adasyn
    ],
    'PR AUC': [
        pr_auc_rf, pr_auc_rf_smote, pr_auc_rf_adasyn,
        pr_auc_xgb, pr_auc_xgb_smote, pr_auc_xgb_adasyn,
        pr_auc_cb, pr_auc_cb_smote, pr_auc_cb_adasyn
    ]
})

# Merge with timing results
results_df = results_df.merge(df_times, left_on='Model', right_on='model', how='left').drop(columns=['model'])

display(results_df)
# Out:
#                  Model  Accuracy  F1 Score  Precision    Recall   ROC AUC  \
# 0         RandomForest  0.999544  0.863158   0.891304  0.836735  0.951882
# 1   RandomForest SMOTE  0.999561  0.861878   0.939759  0.795918  0.955322
# 2  RandomForest ADASYN  0.999561  0.858757   0.962025  0.775510  0.969350
# 3              XGBoost  0.999561  0.864865   0.919540  0.816327  0.972657
# 4        XGBoost SMOTE  0.999579  0.875000   0.893617  0.857143  0.976935
# 5       XGBoost ADASYN  0.999561  0.860335   0.950617  0.785714  0.978208
# 6             CatBoost  0.999631  0.886486   0.942529  0.836735  0.978982
# 7       CatBoost SMOTE  0.999473  0.845361   0.854167  0.836735  0.977722
# 8      CatBoost ADASYN  0.999473  0.842105   0.869565  0.816327  0.977730
#
#      PR AUC
# 0  0.861361
# 1  0.860481
# 2  0.875349
# 3  0.877266
# 4  0.884734
# 5  0.871852
# 6  0.874260
# 7  0.861390
# 8  0.848195

# %%
# Save the results DataFrame to a CSV file
results_df.to_csv('../results/results_summary_tree_models.csv', index=False)
